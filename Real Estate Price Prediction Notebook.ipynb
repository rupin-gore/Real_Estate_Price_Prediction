# %% [markdown]
# # IMPORT LIBRARIES AND DATASETS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
house_df = pd.read_csv('kc_house_data.csv')

# %%
house_df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
house_df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
# 5    101930     1.0           0     0  ...     11        3890           1530
# 6      6819     2.0           0     0  ...      7        1715              0
# 7      9711     1.0           0     0  ...      7        1060              0
# 8      7470     1.0           0     0  ...      7        1050            730
# 9      6560     2.0           0     0  ...      7        1890              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
# 5      2001             0    98053  47.6561 -122.005           4760
# 6      1995             0    98003  47.3097 -122.327           2238
# 7      1963             0    98198  47.4095 -122.315           1650
# 8      1960             0    98146  47.5123 -122.337           1780
# 9      2003             0    98038  47.3684 -122.031           2390
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
# 5      101930
# 6        6819
# 7        9711
# 8        8113
# 9        7570
#
# [10 rows x 21 columns]

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# - **What is the average house price?**
# - **What is the price of the cheapest house?**
# - **What is the average number of bathrooms and bedrooms? round your answer to the lowest value**
# - **What is the maximum number of bedrooms?**

# %%
house_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %% [markdown]
# # PERFORM DATA VISUALIZATION

# %%
sns.scatterplot(x = 'sqft_living', y = 'price', data = house_df)
# Out:
# <Axes: xlabel='sqft_living', ylabel='price'>

# %%
house_df.hist(bins = 20, figsize = (20,20), color = 'indigo')
# Out:
# array([[<Axes: title={'center': 'id'}>,
#         <Axes: title={'center': 'price'}>,
#         <Axes: title={'center': 'bedrooms'}>,
#         <Axes: title={'center': 'bathrooms'}>],
#        [<Axes: title={'center': 'sqft_living'}>,
#         <Axes: title={'center': 'sqft_lot'}>,
#         <Axes: title={'center': 'floors'}>,
#         <Axes: title={'center': 'waterfront'}>],
#        [<Axes: title={'center': 'view'}>,
#         <Axes: title={'center': 'condition'}>,
#         <Axes: title={'center': 'grade'}>,
#         <Axes: title={'center': 'sqft_above'}>],
#        [<Axes: title={'center': 'sqft_basement'}>,
#         <Axes: title={'center': 'yr_built'}>,
#         <Axes: title={'center': 'yr_renovated'}>,
#         <Axes: title={'center': 'zipcode'}>],
#        [<Axes: title={'center': 'lat'}>,
#         <Axes: title={'center': 'long'}>,
#         <Axes: title={'center': 'sqft_living15'}>,
#         <Axes: title={'center': 'sqft_lot15'}>]], dtype=object)

# %%
f, ax = plt.subplots(figsize = (20, 20))
sns.heatmap(house_df.select_dtypes(include=[np.number]).corr(), annot = True)
# Out:
# <Axes: >

# %%
house_df_sample = house_df[ ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'sqft_above', 'sqft_basement', 'yr_built'] ]

# %%
house_df_sample
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot  sqft_above  \
# 0      221900.0         3       1.00         1180      5650        1180
# 1      538000.0         3       2.25         2570      7242        2170
# 2      180000.0         2       1.00          770     10000         770
# 3      604000.0         4       3.00         1960      5000        1050
# 4      510000.0         3       2.00         1680      8080        1680
# ...         ...       ...        ...          ...       ...         ...
# 21608  360000.0         3       2.50         1530      1131        1530
# 21609  400000.0         4       2.50         2310      5813        2310
# 21610  402101.0         2       0.75         1020      1350        1020
# 21611  400000.0         3       2.50         1600      2388        1600
# 21612  325000.0         2       0.75         1020      1076        1020
#
#        sqft_basement  yr_built
# 0                  0      1955
# 1                400      1951
# 2                  0      1933
# 3                910      1965
# 4                  0      1987
# ...              ...       ...
# 21608              0      2009
# 21609              0      2014
# 21610              0      2009
# 21611              0      2004
# 21612              0      2008
#
# [21613 rows x 8 columns]

# %% [markdown]
# - **Using Seaborn, plot the pairplot for the features contained in "house_df_sample"**
# - **Explore the data and perform sanity check**

# %%
sns.pairplot(house_df_sample)

# %% [markdown]
# # PERFORM DATA CLEANING AND FEATURE ENGINEERING

# %%
selected_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'sqft_above', 'sqft_basement']

# %%
X = house_df[selected_features]

# %%
X
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  sqft_above  \
# 0             3       1.00         1180      5650     1.0        1180
# 1             3       2.25         2570      7242     2.0        2170
# 2             2       1.00          770     10000     1.0         770
# 3             4       3.00         1960      5000     1.0        1050
# 4             3       2.00         1680      8080     1.0        1680
# ...         ...        ...          ...       ...     ...         ...
# 21608         3       2.50         1530      1131     3.0        1530
# 21609         4       2.50         2310      5813     2.0        2310
# 21610         2       0.75         1020      1350     2.0        1020
# 21611         3       2.50         1600      2388     2.0        1600
# 21612         2       0.75         1020      1076     2.0        1020
#
#        sqft_basement
# 0                  0
# 1                400
# 2                  0
# 3                910
# 4                  0
# ...              ...
# 21608              0
# 21609              0
# 21610              0
# 21611              0
# 21612              0
#
# [21613 rows x 7 columns]

# %%
y = house_df['price']

# %%
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
X.shape
# Out:
# (21613, 7)

# %%
y.shape
# Out:
# (21613,)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.09090909, 0.125     , 0.06716981, ..., 0.        , 0.09758772,
#         0.        ],
#        [0.09090909, 0.28125   , 0.17207547, ..., 0.4       , 0.20614035,
#         0.08298755],
#        [0.06060606, 0.125     , 0.03622642, ..., 0.        , 0.05263158,
#         0.        ],
#        ...,
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.4       , 0.08004386,
#         0.        ],
#        [0.09090909, 0.3125    , 0.09886792, ..., 0.4       , 0.14364035,
#         0.        ],
#        [0.06060606, 0.09375   , 0.05509434, ..., 0.4       , 0.08004386,
#         0.        ]])

# %%
X_scaled.shape
# Out:
# (21613, 7)

# %%
scaler.data_max_
# Out:
# array([3.300000e+01, 8.000000e+00, 1.354000e+04, 1.651359e+06,
#        3.500000e+00, 9.410000e+03, 4.820000e+03])

# %%
scaler.data_min_
# Out:
# array([  0.,   0., 290., 520.,   1., 290.,   0.])

# %%
y = y.values.reshape(-1,1)

# %%
y_scaled = scaler.fit_transform(y)

# %%
y_scaled
# Out:
# array([[0.01926557],
#        [0.06072131],
#        [0.01377049],
#        ...,
#        [0.04289849],
#        [0.04262295],
#        [0.03278689]])

# %% [markdown]
# # TRAIN A DEEP LEARNING MODEL WITH LIMITED NUMBER OF FEATURES

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.3)

# %%
X_train.shape
# Out:
# (15129, 7)

# %%
X_test.shape
# Out:
# (6484, 7)

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(100, input_dim = 7, activation = 'relu'))
model.add(Dense(100, activation = 'relu'))
model.add(Dense(100, activation = 'relu'))
#Added extra layers
model.add(Dense(200, activation = 'relu'))
model.add(Dense(1, activation = 'linear'))
# Out:
# c:\Users\rupin\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 100)            │           800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 200)            │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │           201 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 41,401 (161.72 KB)
#  Trainable params: 41,401 (161.72 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer = 'Adam', loss = 'mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100, batch_size = 50, validation_split = 0.2)
# Out:
# Epoch 1/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 2/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - val_loss: 9.6765e-04
# Epoch 3/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 4/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0011 - val_loss: 9.9865e-04
# Epoch 5/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 6/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 7/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 8/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 9/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 10/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0011 - val_loss: 0.0010
# Epoch 11/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 9.7021e-04
# Epoch 12/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 13/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7995e-04 - val_loss: 0.0010
# Epoch 14/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 9.4514e-04
# Epoch 15/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.8850e-04 - val_loss: 9.5580e-04
# Epoch 16/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 17/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 9.3975e-04
# Epoch 18/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7666e-04 - val_loss: 9.3298e-04
# Epoch 19/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 20/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9651e-04 - val_loss: 0.0010
# Epoch 21/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7151e-04 - val_loss: 0.0010
# Epoch 22/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 23/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.8426e-04 - val_loss: 9.7641e-04
# Epoch 24/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.4328e-04 - val_loss: 0.0011
# Epoch 25/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 9.9101e-04
# Epoch 26/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3213e-04 - val_loss: 9.7458e-04
# Epoch 27/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 9.2460e-04
# Epoch 28/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4389e-04 - val_loss: 9.3416e-04
# Epoch 29/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.9925e-04 - val_loss: 9.4878e-04
# Epoch 30/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 9.2341e-04
# Epoch 31/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.6236e-04 - val_loss: 9.8546e-04
# Epoch 32/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.8953e-04 - val_loss: 9.3039e-04
# Epoch 33/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8425e-04 - val_loss: 9.7737e-04
# Epoch 34/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.7324e-04 - val_loss: 9.4966e-04
# Epoch 35/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5028e-04 - val_loss: 9.8653e-04
# Epoch 36/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 9.7970e-04
# Epoch 37/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7373e-04 - val_loss: 9.6446e-04
# Epoch 38/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.6350e-04 - val_loss: 9.8058e-04
# Epoch 39/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 9.9618e-04
# Epoch 40/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.8284e-04 - val_loss: 9.3745e-04
# Epoch 41/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.8913e-04 - val_loss: 9.7877e-04
# Epoch 42/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5291e-04 - val_loss: 9.2775e-04
# Epoch 43/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.4412e-04 - val_loss: 9.5428e-04
# Epoch 44/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6338e-04 - val_loss: 9.4050e-04
# Epoch 45/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1746e-04 - val_loss: 9.4575e-04
# Epoch 46/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4138e-04 - val_loss: 9.3714e-04
# Epoch 47/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3616e-04 - val_loss: 9.7810e-04
# Epoch 48/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7733e-04 - val_loss: 9.3893e-04
# Epoch 49/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.5101e-04 - val_loss: 9.4950e-04
# Epoch 50/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4012e-04 - val_loss: 9.1343e-04
# Epoch 51/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4998e-04 - val_loss: 9.5735e-04
# Epoch 52/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5690e-04 - val_loss: 9.3034e-04
# Epoch 53/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.1525e-04 - val_loss: 9.1675e-04
# Epoch 54/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2439e-04 - val_loss: 9.8671e-04
# Epoch 55/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.2998e-04 - val_loss: 9.1175e-04
# Epoch 56/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4503e-04 - val_loss: 9.4764e-04
# Epoch 57/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2119e-04 - val_loss: 9.4685e-04
# Epoch 58/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.6952e-04 - val_loss: 9.8696e-04
# Epoch 59/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.8524e-04 - val_loss: 9.9227e-04
# Epoch 60/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7715e-04 - val_loss: 9.3302e-04
# Epoch 61/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.9586e-04 - val_loss: 0.0010
# Epoch 62/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.0178e-04 - val_loss: 9.8758e-04
# Epoch 63/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5275e-04 - val_loss: 9.5704e-04
# Epoch 64/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.0653e-04 - val_loss: 9.7509e-04
# Epoch 65/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.4171e-04 - val_loss: 9.4136e-04
# Epoch 66/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.5112e-04 - val_loss: 9.4927e-04
# Epoch 67/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.6007e-04 - val_loss: 0.0010
# Epoch 68/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.2041e-04 - val_loss: 9.5492e-04
# Epoch 69/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.2679e-04 - val_loss: 9.5717e-04
# Epoch 70/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.9502e-04 - val_loss: 9.9928e-04
# Epoch 71/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.0002e-04 - val_loss: 9.4280e-04
# Epoch 72/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.5207e-04 - val_loss: 9.6041e-04
# Epoch 73/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.0074e-04 - val_loss: 9.8003e-04
# Epoch 74/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2877e-04 - val_loss: 0.0010
# Epoch 75/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3987e-04 - val_loss: 9.8670e-04
# Epoch 76/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3557e-04 - val_loss: 9.8310e-04
# Epoch 77/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0010 - val_loss: 9.8135e-04
# Epoch 78/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.9412e-04 - val_loss: 9.8258e-04
# Epoch 79/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.7986e-04 - val_loss: 9.2051e-04
# Epoch 80/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3075e-04 - val_loss: 0.0010
# Epoch 81/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.8445e-04 - val_loss: 9.5759e-04
# Epoch 82/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.6103e-04 - val_loss: 0.0010
# Epoch 83/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.3294e-04 - val_loss: 9.2567e-04
# Epoch 84/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.6992e-04 - val_loss: 9.2425e-04
# Epoch 85/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.0625e-04 - val_loss: 9.8589e-04
# Epoch 86/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.8081e-04 - val_loss: 9.6799e-04
# Epoch 87/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.2199e-04 - val_loss: 9.6997e-04
# Epoch 88/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.0510e-04 - val_loss: 9.7876e-04
# Epoch 89/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.1056e-04 - val_loss: 9.8173e-04
# Epoch 90/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7385e-04 - val_loss: 9.7609e-04
# Epoch 91/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.1199e-04 - val_loss: 9.6207e-04
# Epoch 92/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.1640e-04 - val_loss: 9.8943e-04
# Epoch 93/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.0037e-04 - val_loss: 9.7201e-04
# Epoch 94/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.9812e-04 - val_loss: 9.6537e-04
# Epoch 95/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.7726e-04 - val_loss: 9.7678e-04
# Epoch 96/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.9898e-04 - val_loss: 9.7029e-04
# Epoch 97/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.8181e-04 - val_loss: 9.7814e-04
# Epoch 98/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2413e-04 - val_loss: 9.3872e-04
# Epoch 99/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 8.6411e-04 - val_loss: 9.2867e-04
# Epoch 100/100
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.7688e-04 - val_loss: 9.9501e-04

# %% [markdown]
# - **Change the architecture of the network by adding an additional dense layer with 200 neurons. Use "Relu" as an activation function**
# - **How many trainable parameters does the new network has?**

# %% [markdown]
# # EVALUATE TRAINED DEEP LEARNING MODEL PERFORMANCE

# %%
epochs_hist.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.xlabel('Epoch')
plt.ylabel('Training and Validation Loss')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
# 'bedrooms','bathrooms','sqft_living','sqft_lot','floors', 'sqft_above', 'sqft_basement'
X_test_1 = np.array([[ 4, 3, 1960, 5000, 1, 2000, 3000 ]])

scaler_1 = MinMaxScaler()
X_test_scaled_1 = scaler_1.fit_transform(X_test_1)

y_predict_1 = model.predict(X_test_scaled_1)

y_predict_1 = scaler.inverse_transform(y_predict_1)
y_predict_1
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# array([[249904.62]], dtype=float32)

# %%
y_predict = model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
# Out:
# 203/203 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step
# Text(0, 0.5, 'True Values')

# %%
y_predict_orig = scaler.inverse_transform(y_predict)
y_test_orig = scaler.inverse_transform(y_test)

# %%
plt.plot(y_test_orig, y_predict_orig, "^", color = 'r')
plt.xlabel('Model Predictions')
plt.ylabel('True Values')
plt.xlim(0, 5000000)
plt.ylim(0, 3000000)
# Out:
# (0.0, 3000000.0)

# %%
k = X_test.shape[1]
n = len(X_test)
n
# Out:
# 6484

# %%
k
# Out:
# 7

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 246923.108
# MSE = 60971021478.647095
# MAE = 167266.95937355413
# R2 = 0.5403203822846845
# Adjusted R2 = 0.5398235080839422

# %% [markdown]
# # TRAIN AND EVALUATE A DEEP LEARNING MODEL WITH INCREASED NUMBER OF FEATURES (INDEPENDANT VARIABLES)

# %%
selected_features = ['bedrooms','bathrooms','sqft_living','sqft_lot','floors', 'sqft_above', 'sqft_basement', 'waterfront', 'view', 'condition', 'grade', 'sqft_above', 'yr_built', 
'yr_renovated', 'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15']

X = house_df[selected_features]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
y = house_df['price']

# %%
y = y.values.reshape(-1,1)
y_scaled = scaler.fit_transform(y)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size = 0.25)

# %%
import tensorflow.keras
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense

model = Sequential()
model.add(Dense(10, input_dim = 19, activation = 'relu'))
model.add(Dense(10, activation = 'relu'))
#Added extra layers
model.add(Dense(200, activation = 'relu'))
model.add(Dense(200, activation = 'relu'))
model.add(Dense(1, activation = 'linear'))
# Out:
# c:\Users\rupin\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
epochs_hist = model.fit(X_train, y_train, epochs = 100, batch_size = 50, verbose = 1, validation_split = 0.2)
# Out:
# Epoch 1/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0017 - val_loss: 7.5795e-04
# Epoch 2/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6252e-04 - val_loss: 6.5445e-04
# Epoch 3/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.7168e-04 - val_loss: 5.9572e-04
# Epoch 4/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.7413e-04 - val_loss: 5.4316e-04
# Epoch 5/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8133e-04 - val_loss: 5.3427e-04
# Epoch 6/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.4194e-04 - val_loss: 6.0635e-04
# Epoch 7/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2039e-04 - val_loss: 5.1809e-04
# Epoch 8/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.4489e-04 - val_loss: 6.6319e-04
# Epoch 9/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.0020e-04 - val_loss: 5.3296e-04
# Epoch 10/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.4262e-04 - val_loss: 5.1448e-04
# Epoch 11/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.7091e-04 - val_loss: 5.7686e-04
# Epoch 12/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.1732e-04 - val_loss: 4.7875e-04
# Epoch 13/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.4267e-04 - val_loss: 5.8132e-04
# Epoch 14/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6244e-04 - val_loss: 4.5937e-04
# Epoch 15/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3599e-04 - val_loss: 4.7894e-04
# Epoch 16/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5460e-04 - val_loss: 4.3172e-04
# Epoch 17/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6569e-04 - val_loss: 5.2523e-04
# Epoch 18/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.0377e-04 - val_loss: 4.3407e-04
# Epoch 19/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.5174e-04 - val_loss: 4.7707e-04
# Epoch 20/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2320e-04 - val_loss: 4.1935e-04
# Epoch 21/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.8298e-04 - val_loss: 4.1792e-04
# Epoch 22/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.8402e-04 - val_loss: 4.9159e-04
# Epoch 23/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.9270e-04 - val_loss: 4.2699e-04
# Epoch 24/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.4943e-04 - val_loss: 3.9543e-04
# Epoch 25/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.2468e-04 - val_loss: 4.2046e-04
# Epoch 26/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.8790e-04 - val_loss: 3.6391e-04
# Epoch 27/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.5837e-04 - val_loss: 3.7068e-04
# Epoch 28/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.4468e-04 - val_loss: 3.7333e-04
# Epoch 29/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.2092e-04 - val_loss: 3.6122e-04
# Epoch 30/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.3234e-04 - val_loss: 3.5968e-04
# Epoch 31/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.2739e-04 - val_loss: 3.7036e-04
# Epoch 32/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.4367e-04 - val_loss: 4.0547e-04
# Epoch 33/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.3127e-04 - val_loss: 3.5259e-04
# Epoch 34/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.1497e-04 - val_loss: 3.3449e-04
# Epoch 35/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.1231e-04 - val_loss: 3.2086e-04
# Epoch 36/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.7952e-04 - val_loss: 3.1718e-04
# Epoch 37/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.9119e-04 - val_loss: 3.7351e-04
# Epoch 38/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.8692e-04 - val_loss: 3.7140e-04
# Epoch 39/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.9990e-04 - val_loss: 3.3736e-04
# Epoch 40/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.8431e-04 - val_loss: 3.1523e-04
# Epoch 41/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.8551e-04 - val_loss: 3.3752e-04
# Epoch 42/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.9537e-04 - val_loss: 2.9752e-04
# Epoch 43/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.3044e-04 - val_loss: 3.0919e-04
# Epoch 44/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.7912e-04 - val_loss: 3.0638e-04
# Epoch 45/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5902e-04 - val_loss: 3.2850e-04
# Epoch 46/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.6909e-04 - val_loss: 3.1061e-04
# Epoch 47/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5879e-04 - val_loss: 3.6690e-04
# Epoch 48/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.0498e-04 - val_loss: 3.0053e-04
# Epoch 49/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5593e-04 - val_loss: 3.0612e-04
# Epoch 50/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.6863e-04 - val_loss: 2.9821e-04
# Epoch 51/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5479e-04 - val_loss: 2.9462e-04
# Epoch 52/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5974e-04 - val_loss: 2.9226e-04
# Epoch 53/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.6208e-04 - val_loss: 3.0423e-04
# Epoch 54/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2670e-04 - val_loss: 3.4804e-04
# Epoch 55/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5817e-04 - val_loss: 2.8742e-04
# Epoch 56/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5110e-04 - val_loss: 2.8899e-04
# Epoch 57/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.4311e-04 - val_loss: 2.9891e-04
# Epoch 58/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.4733e-04 - val_loss: 2.8587e-04
# Epoch 59/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.4051e-04 - val_loss: 2.9248e-04
# Epoch 60/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5096e-04 - val_loss: 3.1177e-04
# Epoch 61/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.6127e-04 - val_loss: 4.1752e-04
# Epoch 62/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.8549e-04 - val_loss: 2.9582e-04
# Epoch 63/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5374e-04 - val_loss: 2.7747e-04
# Epoch 64/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2837e-04 - val_loss: 2.7499e-04
# Epoch 65/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.3528e-04 - val_loss: 3.1057e-04
# Epoch 66/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.4320e-04 - val_loss: 3.3950e-04
# Epoch 67/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2674e-04 - val_loss: 3.7141e-04
# Epoch 68/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.4738e-04 - val_loss: 3.0918e-04
# Epoch 69/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2835e-04 - val_loss: 2.5705e-04
# Epoch 70/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.0411e-04 - val_loss: 3.6399e-04
# Epoch 71/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.4864e-04 - val_loss: 2.7954e-04
# Epoch 72/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5956e-04 - val_loss: 2.7987e-04
# Epoch 73/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.3139e-04 - val_loss: 3.4255e-04
# Epoch 74/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2704e-04 - val_loss: 2.5939e-04
# Epoch 75/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.3162e-04 - val_loss: 3.9949e-04
# Epoch 76/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.6984e-04 - val_loss: 2.6558e-04
# Epoch 77/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.3140e-04 - val_loss: 3.5517e-04
# Epoch 78/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.1965e-04 - val_loss: 2.8111e-04
# Epoch 79/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.4954e-04 - val_loss: 2.6357e-04
# Epoch 80/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.1841e-04 - val_loss: 2.6697e-04
# Epoch 81/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5206e-04 - val_loss: 2.5897e-04
# Epoch 82/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2079e-04 - val_loss: 2.6650e-04
# Epoch 83/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2253e-04 - val_loss: 2.7823e-04
# Epoch 84/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.3302e-04 - val_loss: 2.8647e-04
# Epoch 85/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.3471e-04 - val_loss: 2.6378e-04
# Epoch 86/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2148e-04 - val_loss: 2.9677e-04
# Epoch 87/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2641e-04 - val_loss: 2.5522e-04
# Epoch 88/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2476e-04 - val_loss: 2.5164e-04
# Epoch 89/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.0498e-04 - val_loss: 2.5780e-04
# Epoch 90/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2821e-04 - val_loss: 2.6168e-04
# Epoch 91/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2642e-04 - val_loss: 2.8256e-04
# Epoch 92/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.1798e-04 - val_loss: 2.7086e-04
# Epoch 93/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2646e-04 - val_loss: 2.8202e-04
# Epoch 94/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.9544e-04 - val_loss: 2.6480e-04
# Epoch 95/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.1716e-04 - val_loss: 2.7197e-04
# Epoch 96/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.0725e-04 - val_loss: 2.8804e-04
# Epoch 97/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2717e-04 - val_loss: 2.6066e-04
# Epoch 98/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.1467e-04 - val_loss: 2.5748e-04
# Epoch 99/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.0604e-04 - val_loss: 2.6036e-04
# Epoch 100/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.0796e-04 - val_loss: 2.5082e-04

# %%
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])
plt.title('Model Loss Progress During Training')
plt.ylabel('Training and Validation Loss')
plt.xlabel('Epoch number')
plt.legend(['Training Loss', 'Validation Loss'])

# %%
y_predict = model.predict(X_test)
plt.plot(y_test, y_predict, "^", color = 'r')
plt.xlabel("Model Predictions")
plt.ylabel("True Value (ground Truth)")
plt.title('Linear Regression Predictions')
plt.show()
# Out:
# 169/169 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
y_predict_orig = scaler.inverse_transform(y_predict)
y_test_orig = scaler.inverse_transform(y_test)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from math import sqrt

RMSE = float(format(np.sqrt(mean_squared_error(y_test_orig, y_predict_orig)),'.3f'))
MSE = mean_squared_error(y_test_orig, y_predict_orig)
MAE = mean_absolute_error(y_test_orig, y_predict_orig)
r2 = r2_score(y_test_orig, y_predict_orig)
adj_r2 = 1-(1-r2)*(n-1)/(n-k-1)

print('RMSE =',RMSE, '\nMSE =',MSE, '\nMAE =',MAE, '\nR2 =', r2, '\nAdjusted R2 =', adj_r2)
# Out:
# RMSE = 124139.148
# MSE = 15410528112.077303
# MAE = 72944.10507407707
# R2 = 0.8877664016972852
# Adjusted R2 = 0.8876450868133878

# %% [markdown]
# - **Change the architecture of the network to increase the coefficient of determination to at least 0.86.**
